# %%
import numpy as np
import pandas as pd

# %%
#Knowing the Encoding of the dataset 
import chardet

with open("data.csv", "rb") as f:
    result = chardet.detect(f.read())
    print(result)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.7257971165545478, 'language': ''}

# %%
df = pd.read_csv("data.csv",encoding="Windows-1252")

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# ## PROJECT FLOW
#    1. DATA CLEANING
#    2. EDA
#    3. TEXT PREPROCESSING
#    4. MODEL BUILDING
#    5. EVALUATION
#    6. IMPROVEMENT
#    7. DEPLOYMENT

# %% [markdown]
# ## DATA CLEANING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
#dropping the last 3 cols as they only containg NULL values


df.drop(columns=["Unnamed: 2","Unnamed: 3","Unnamed: 4"],inplace=True)

# %%
df.sample(5)
# Out:
#         v1                                                 v2
# 2480  spam  Urgent! call 09066612661 from landline. Your c...
# 4045  spam    Win a å£1000 cash prize or a prize worth å£5000
# 4472   ham                           S but not able to sleep.
# 2635   ham       Tiwary to rcb.battle between bang and kochi.
# 4116   ham  Sure thing big man. i have hockey elections at...

# %%
# renaming the cols names as it is not so clear
df.rename(columns = {"v1":"target","v2":"text"},inplace = True)

# %%
df.sample(5)
# Out:
#      target                                               text
# 5206    ham        I will reach ur home in  &lt;#&gt;  minutes
# 1549    ham  Dude sux for snake. He got old and raiden got ...
# 2547   spam  Text82228>> Get more ringtones, logos and game...
# 1931    ham                What pa tell me.. I went to bath:-)
# 4729    ham  I dont know ask to my brother. Nothing problem...

# %%
#now change target values to 0 or 1
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df["target"] = encoder.fit_transform(df["target"])

# %%
df.sample(5)
# Out:
#       target                                               text
# 3022       0   You are a very very very very bad girl. Or lady.
# 5193       0              It's wylie, you in tampa or sarasota?
# 3096       0              Yo, you at jp and hungry like a mofo?
# 1001       1  Please call our customer service representativ...
# 3064       0                        Sounds good, keep me posted

# %%
# check for missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
#check for duplicate values
df.duplicated().sum()
# Out:
# 403

# %%
df = df.drop_duplicates(keep="first")

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df["target"].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df["target"].value_counts(),labels =["ham","spam"],autopct="%0.2f")
plt.show()

# %%
#data is imabalanced

# %%
# !pip install nltk

import nltk
# Out:
# Requirement already satisfied: nltk in c:\users\manas yadav\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\manas yadav\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\manas yadav\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\manas yadav\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\manas yadav\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\manas yadav\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Manas
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df["num_characters"] = df["text"].apply(len)

# %%
df.head(5)
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
#num of words
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
df['num_words'] = df['text'].apply(lambda x: len(tokenizer.tokenize(x)))

# %%
df.head(5)
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         23
# 1          8
# 2         36
# 3         13
# 4         15

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
df["num_sentences"] = df["text"].apply(lambda x: len(list(nlp(str(x)).sents)))

# %%
df.head(5)
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         23              3
# 1          8              2
# 2         36              2
# 3         13              2
# 4         15              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    17.695299       2.100600
# std         58.236293    12.672457       1.456788
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    14.000000       2.000000
# 75%        117.000000    25.000000       3.000000
# max        910.000000   214.000000      27.000000

# %%
#ham
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    16.452613       1.961470
# std         56.358207    12.858450       1.401099
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       2.000000
# 75%         90.000000    21.000000       2.000000
# max        910.000000   214.000000      27.000000

# %%
#spam
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   26.289433       3.062787
# std         30.137753    6.579189       1.471835
# min         13.000000    2.000000       1.000000
# 25%        132.000000   24.000000       2.000000
# 50%        149.000000   28.000000       3.000000
# 75%        157.000000   30.000000       4.000000
# max        224.000000   41.000000       9.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'],color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##3. DATA PROCESSING

# %% [markdown]
# -Lower Case
# -Tokenization
# -Removing Special characters
# -Removing stop words and punctuation
# -Stemming

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
len(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Manas
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 198

# %%
import nltk
nltk.download('punkt_tab')
import string
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Manas
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
#stemming
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem("love")
# Out:
# 'love'

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)

    y=[]
    for i in text:
        if (i.isalnum()):
            y.append(i)

    text = y[:]
    y.clear()
    for i in text:
        if i not in stopwords.words("english") and i not in string.punctuation:
            y.append(i)

    text = y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
        
    return " ".join(y)

# %%
transform_text("How are you Manas?")
# Out:
# 'mana'

# %%
df["text"][10]
# Out:
# "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today."

# %%
df["transformed_text"] = df["text"].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         23              3  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         36              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              2                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
#now we will use text and transformed_text columns further

# %%
from wordcloud import WordCloud
wc = WordCloud(width = 500,height=500,background_color="black")

# %%
 spam_wc  = wc.generate(df[df["target"] == 1]["transformed_text"].str.cat(sep=" "))

# %%
plt.figure(figsize=(10,10))
plt.imshow(spam_wc)

# %%
ham_wc  = wc.generate(df[df["target"] == 0]["transformed_text"].str.cat(sep=" "))

# %%
plt.figure(figsize=(10,10))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         23              3  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         36              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              2                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
spam_corpus = []
for msg in df[df["target"] == 1]["transformed_text"].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
sns.barplot(x = pd.DataFrame(Counter(spam_corpus).most_common(30))[0],y = pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation="vertical")
plt.show()

# %%
ham_corpus =[]
for msg in df[df["target"]==0]["transformed_text"].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
sns.barplot(x=pd.DataFrame(Counter(ham_corpus).most_common(30))[0],y=pd.DataFrame(Counter(ham_corpus).most_common(30))[1])
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ## 4. MODEL BUILDING

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = tfidf.fit_transform(df["transformed_text"]).toarray()

# %%
import numpy as np
import pandas as pd

# %%
#Knowing the Encoding of the dataset 
import chardet

with open("data.csv", "rb") as f:
    result = chardet.detect(f.read())
    print(result)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.7257971165545478, 'language': ''}

# %%
df = pd.read_csv("data.csv",encoding="Windows-1252")

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# ## PROJECT FLOW
#    1. DATA CLEANING
#    2. EDA
#    3. TEXT PREPROCESSING
#    4. MODEL BUILDING
#    5. EVALUATION
#    6. IMPROVEMENT
#    7. DEPLOYMENT

# %% [markdown]
# ## DATA CLEANING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
#dropping the last 3 cols as they only containg NULL values


df.drop(columns=["Unnamed: 2","Unnamed: 3","Unnamed: 4"],inplace=True)

# %%
df.sample(5)
# Out:
#         v1                                                 v2
# 2480  spam  Urgent! call 09066612661 from landline. Your c...
# 4045  spam    Win a å£1000 cash prize or a prize worth å£5000
# 4472   ham                           S but not able to sleep.
# 2635   ham       Tiwary to rcb.battle between bang and kochi.
# 4116   ham  Sure thing big man. i have hockey elections at...

# %%
# renaming the cols names as it is not so clear
df.rename(columns = {"v1":"target","v2":"text"},inplace = True)

# %%
df.sample(5)
# Out:
#      target                                               text
# 5206    ham        I will reach ur home in  &lt;#&gt;  minutes
# 1549    ham  Dude sux for snake. He got old and raiden got ...
# 2547   spam  Text82228>> Get more ringtones, logos and game...
# 1931    ham                What pa tell me.. I went to bath:-)
# 4729    ham  I dont know ask to my brother. Nothing problem...

# %%
#now change target values to 0 or 1
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df["target"] = encoder.fit_transform(df["target"])

# %%
df.sample(5)
# Out:
#       target                                               text
# 3022       0   You are a very very very very bad girl. Or lady.
# 5193       0              It's wylie, you in tampa or sarasota?
# 3096       0              Yo, you at jp and hungry like a mofo?
# 1001       1  Please call our customer service representativ...
# 3064       0                        Sounds good, keep me posted

# %%
# check for missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
#check for duplicate values
df.duplicated().sum()
# Out:
# 403

# %%
df = df.drop_duplicates(keep="first")

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df["target"].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df["target"].value_counts(),labels =["ham","spam"],autopct="%0.2f")
plt.show()

# %%
#data is imabalanced

# %%
# !pip install nltk

import nltk
# Out:
# Requirement already satisfied: nltk in c:\users\manas yadav\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\manas yadav\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\manas yadav\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\manas yadav\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\manas yadav\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\manas yadav\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Manas
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df["num_characters"] = df["text"].apply(len)

# %%
df.head(5)
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
#num of words
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
df['num_words'] = df['text'].apply(lambda x: len(tokenizer.tokenize(x)))

# %%
df.head(5)
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         23
# 1          8
# 2         36
# 3         13
# 4         15

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
df["num_sentences"] = df["text"].apply(lambda x: len(list(nlp(str(x)).sents)))

# %%
df.head(5)
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         23              3
# 1          8              2
# 2         36              2
# 3         13              2
# 4         15              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    17.695299       2.100600
# std         58.236293    12.672457       1.456788
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    14.000000       2.000000
# 75%        117.000000    25.000000       3.000000
# max        910.000000   214.000000      27.000000

# %%
#ham
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    16.452613       1.961470
# std         56.358207    12.858450       1.401099
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       2.000000
# 75%         90.000000    21.000000       2.000000
# max        910.000000   214.000000      27.000000

# %%
#spam
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   26.289433       3.062787
# std         30.137753    6.579189       1.471835
# min         13.000000    2.000000       1.000000
# 25%        132.000000   24.000000       2.000000
# 50%        149.000000   28.000000       3.000000
# 75%        157.000000   30.000000       4.000000
# max        224.000000   41.000000       9.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'],color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##3. DATA PROCESSING

# %% [markdown]
# -Lower Case
# -Tokenization
# -Removing Special characters
# -Removing stop words and punctuation
# -Stemming

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")
len(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Manas
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 198

# %%
import nltk
nltk.download('punkt_tab')
import string
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Manas
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
#stemming
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem("love")
# Out:
# 'love'

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)

    y=[]
    for i in text:
        if (i.isalnum()):
            y.append(i)

    text = y[:]
    y.clear()
    for i in text:
        if i not in stopwords.words("english") and i not in string.punctuation:
            y.append(i)

    text = y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
        
    return " ".join(y)

# %%
transform_text("How are you Manas?")
# Out:
# 'mana'

# %%
df["text"][10]
# Out:
# "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today."

# %%
df["transformed_text"] = df["text"].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         23              3  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         36              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              2                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
#now we will use text and transformed_text columns further

# %%
from wordcloud import WordCloud
wc = WordCloud(width = 500,height=500,background_color="black")

# %%
 spam_wc  = wc.generate(df[df["target"] == 1]["transformed_text"].str.cat(sep=" "))

# %%
plt.figure(figsize=(10,10))
plt.imshow(spam_wc)

# %%
ham_wc  = wc.generate(df[df["target"] == 0]["transformed_text"].str.cat(sep=" "))

# %%
plt.figure(figsize=(10,10))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         23              3  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         36              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              2                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
spam_corpus = []
for msg in df[df["target"] == 1]["transformed_text"].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
sns.barplot(x = pd.DataFrame(Counter(spam_corpus).most_common(30))[0],y = pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation="vertical")
plt.show()

# %%
ham_corpus =[]
for msg in df[df["target"]==0]["transformed_text"].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
sns.barplot(x=pd.DataFrame(Counter(ham_corpus).most_common(30))[0],y=pd.DataFrame(Counter(ham_corpus).most_common(30))[1])
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# ## 4. MODEL BUILDING

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=7000)

# %%
X = tfidf.fit_transform(df["transformed_text"]).toarray()

# %%
X.shape
# Out:
# (5169, 6708)

# %%
y = df["target"].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state =2)

# %%
 from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8762088974854932
# [[793 103]
#  [ 25 113]]
# 0.5231481481481481

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9593810444874274
# [[896   0]
#  [ 42  96]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9700193423597679
# [[893   3]
#  [ 28 110]]
# 0.9734513274336283

# %%
import pickle
pickle.dump(tfidf,open("vectorizer.pkl","wb"))
pickle.dump(mnb,open("model.pkl","wb"))

# %%
X.shape
# Out:
# (5169, 6708)

# %%
y = df["target"].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state =2)

# %%
 from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8762088974854932
# [[793 103]
#  [ 25 113]]
# 0.5231481481481481

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9593810444874274
# [[896   0]
#  [ 42  96]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9700193423597679
# [[893   3]
#  [ 28 110]]
# 0.9734513274336283

# %%
import pickle
pickle.dump(tfidf,open("vectorizer.pkl","wb"))
pickle.dump(mnb,open("model.pkl","wb"))
